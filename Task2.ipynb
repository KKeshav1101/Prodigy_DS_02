# %% [markdown]
# # EXPLORATORY DATA ANALYSIS on TITANIC DATASET

# %% [markdown]
# ## PART 1: Analysis of features

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/kaggle/input/titanic/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Attributes to fix : Age, cabin and embarked

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct="%1.1f%%",ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot(data,x='Survived',ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ## Types of Features

# %% [markdown]
# ### Categorical Features
# A categorical varibale is one that has two or more discrete categories and </br> each value in that feature can be categories by them. For example,
# gender is a categorical variable having two categories (male and female). Now we can't sort or give any ordering to such variables.

# %% [markdown]
# ### Ordinal Features
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values.
# Example : PClass

# %% [markdown]
# ### Coninuous Feature
# A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.
#
# Continous Features in the dataset: Age

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot(data,x='Sex',hue='Survived',ax=ax[1])
ax[1].set_title('Sex: Survived vs dead')
plt.show()

# %% [markdown]
# The number of men on the ship >> the number of women but still the number of women saved is twice the number of men saved which makes sense.

# %% [markdown]
# ### PCLASS -> ORDINAL FEATURE

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_59047_row0_col0, #T_59047_row1_col1, #T_59047_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_59047_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_59047_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_59047_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_59047_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_59047_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_59047_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_59047_row3_col0, #T_59047_row3_col1, #T_59047_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_59047">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_59047_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_59047_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=["#CD7F32","#FFDF00","#D3D3D3"],ax=ax[0])
ax[0].set_title('Number of Passengers by Pclass')
ax[0].set_ylabel('Count')
sns.countplot(data,x='Pclass',hue='Survived',ax=ax[1])
ax[1].set_title('Pclass : Survived vs Dead')
plt.show()

# %% [markdown]
# PClass 1 had greater priority for rescue

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_80854_row0_col0, #T_80854_row0_col1, #T_80854_row0_col3, #T_80854_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_80854_row0_col2, #T_80854_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_80854_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_80854_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_80854_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_80854_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_80854_row2_col1, #T_80854_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_80854_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_80854_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_80854_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_80854_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Age-> Continuous Feature

# %%
print('Oldest Passenger was of :',data['Age'].max(),'Years')
print('Youngest Passenger was of :',data['Age'].max(),'Years')
print('Average age on the ship :',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of : 80.0 Years
# Youngest Passenger was of : 80.0 Years
# Average age on the ship : 29.69911764705882 Years

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot(data,x="Pclass",y='Age',hue="Survived",split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot(data,x="Sex",y="Age",hue="Survived",split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# Observations:¶ </br>
# 1)The number of children increases with Pclass and the survival rate for passenegers below Age 10(i.e children) looks to be good irrespective of the Pclass.
#
# 2)Survival chances for Passenegers aged 20-50 from Pclass1 is high and is even better for Women.
#
# 3)For males, the survival chances decreases with an increase in age.

# %% [markdown]
# **name -> feature**

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_7f6ba_row0_col0, #T_7f6ba_row0_col1, #T_7f6ba_row0_col3, #T_7f6ba_row0_col4, #T_7f6ba_row0_col5, #T_7f6ba_row0_col7, #T_7f6ba_row0_col8, #T_7f6ba_row0_col12, #T_7f6ba_row0_col15, #T_7f6ba_row0_col16, #T_7f6ba_row1_col2, #T_7f6ba_row1_col6, #T_7f6ba_row1_col9, #T_7f6ba_row1_col10, #T_7f6ba_row1_col11, #T_7f6ba_row1_col13, #T_7f6ba_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7f6ba_row0_col2, #T_7f6ba_row0_col6, #T_7f6ba_row0_col9, #T_7f6ba_row0_col10, #T_7f6ba_row0_col11, #T_7f6ba_row0_col13, #T_7f6ba_row0_col14, #T_7f6ba_row1_col0, #T_7f6ba_row1_col1, #T_7f6ba_row1_col3, #T_7f6ba_row1_col4, #T_7f6ba_row1_col5, #T_7f6ba_row1_col7, #T_7f6ba_row1_col8, #T_7f6ba_row1_col12, #T_7f6ba_row1_col15, #T_7f6ba_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7f6ba">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
# Out:
# /tmp/ipykernel_74/417967907.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# # FILLING NAN AGES

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived=0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived=1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# The toddlers age<5 and were saved in large numbers
# The oldest passenger was saved and the maximum number of deaths were in the age group 30-40

# %% [markdown]
# Embarked -> Categorical Value

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_5f9f2_row0_col0, #T_5f9f2_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_5f9f2_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_5f9f2_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_5f9f2_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_5f9f2_row0_col4, #T_5f9f2_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_5f9f2_row1_col0, #T_5f9f2_row3_col0, #T_5f9f2_row3_col1, #T_5f9f2_row3_col2, #T_5f9f2_row3_col3, #T_5f9f2_row3_col4, #T_5f9f2_row4_col0, #T_5f9f2_row4_col2, #T_5f9f2_row4_col3, #T_5f9f2_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5f9f2_row1_col1, #T_5f9f2_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_5f9f2_row1_col3, #T_5f9f2_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_5f9f2_row2_col0, #T_5f9f2_row5_col1 {
#   background-color: #e6f266;
# ...

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot(data,x='Embarked',ax=ax[0,0])
ax[0,0].set_title('No. of passengers Boarded')
sns.countplot(data,x='Embarked',hue='Sex',ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for embarked')
sns.countplot(data,hue='Pclass',x='Embarked',ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot(data,x='Embarked',hue='Pclass',ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.show()

# %% [markdown]
# **Observations :**
# 1. Maximum passengers boards from S. Majority of them from Pclass 3 which also makes sense.
# 2. Passengers from C look to be lucky as a good proportion of them survived. This coulld be because of the rescue of most Pclass 1 and Pclass 2 passengers.
# 3. The embark S looks to the port from where majority of the rich people boarded. Still the chances for survival is low here, that is because many passengers from Pclass 3 around 81% didn't survive.
# 4. Port Q had almost 95% of the passengers were from Pclass3.

# %% [markdown]
# **Filling Embarked Nan**

# %%
data['Embarked'].fillna('S',inplace=True)
# Out:
# /tmp/ipykernel_74/1306493021.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# ## SibSp -> Discrete Feature

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_11877_row0_col0, #T_11877_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_11877_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_11877_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_11877_row2_col0, #T_11877_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_11877_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_11877_row3_col0, #T_11877_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_11877_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_11877_row5_col0, #T_11877_row5_col1, #T_11877_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_11877_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_11877">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
# ...

# %%
fig,ax=plt.subplots(1,1)
sns.barplot(data,x='SibSp',y='Survived')
ax.set_title('SibSp vs Survived')
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_019f5_row0_col0, #T_019f5_row0_col1, #T_019f5_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_019f5_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_019f5_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_019f5_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_019f5_row2_col0, #T_019f5_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_019f5_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_019f5_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_019f5_row3_col0, #T_019f5_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_019f5_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_019f5_row4_col0, #T_019f5_row4_col1, #T_019f5_row5_col0, #T_019f5_row5_col1, #T_019f5_row5_col2, #T_019f5_row6_col0, #T_019f5_row6_col1 {
#   background-color: #ffff66;
# ...

# %% [markdown]
# **Observations :**
# The barplot shows that is a passenger is alone on board with no siblings, he/she has a survival rate of 34.5%. The graph decreases if the number of siblings increase. This makes sense because if my family is onboard, I will try to save them instead of saving myself first.
# Crosstab shows that person with SibSp>5 were all in Pclass3. It is imminent that all the large families in Pclass3(>3) died.

# %% [markdown]
# ## Parch

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient()
# Out:
# <style type="text/css">
# #T_c8d11_row0_col0, #T_c8d11_row0_col1, #T_c8d11_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c8d11_row1_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_c8d11_row1_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_c8d11_row1_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_c8d11_row2_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_c8d11_row2_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c8d11_row2_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_c8d11_row3_col0, #T_c8d11_row4_col1, #T_c8d11_row5_col0, #T_c8d11_row5_col1, #T_c8d11_row6_col0, #T_c8d11_row6_col1, #T_c8d11_row6_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c8d11_row3_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c8d11_row3_col2, #T_c8d11_row4_col0, #T_c8d11_row4_col2 {
#   background-color: #fef6fb;
# ...

# %%
f,ax=plt.subplots(1,1)
sns.barplot(data,x='Parch',y='Survived')
ax.set_title('Parch vs Survived')
plt.show()

# %% [markdown]
# ## Fare -> Continuous Feature

# %%
print('Highest Fare was :',data['Fare'].max())
print('Lowest Fare was :',data['Fare'].min())
print('Average Fare was :',data['Fare'].mean())
# Out:
# Highest Fare was : 512.3292
# Lowest Fare was : 0.0
# Average Fare was : 32.204207968574636

# %%
f,ax = plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()
# Out:
# /tmp/ipykernel_74/1770519167.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_74/1770519167.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %% [markdown]
# ### Observations in a nutshell for all features :
# Sex: The chance of survival for women is high as compared to men.
#
# Pclass:There is a visible trend that being a 1st class passenger gives you better chances of survival. The survival rate for Pclass3 is very low. For women, the chance of survival from Pclass1 is almost 1 and is high too for those from Pclass2. Money Wins!!!.
#
# Age: Children less than 5-10 years do have a high chance of survival. Passengers between age group 15 to 35 died a lot.
#
# Embarked: This is a very interesting feature. The chances of survival at C looks to be better than even though the majority of Pclass1 passengers got up at S. Passengers at Q were all from Pclass3.
#
# Parch+SibSp: Having 1-2 siblings,spouse on board or 1-3 Parents shows a greater chance of probablity rather than being alone or having a large family travelling with you.

# %%
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_5d3c3_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5d3c3_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_5d3c3_row2_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_5d3c3_row3_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_5d3c3_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5d3c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d3c3_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_band</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d3c3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5d3c3_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
# ...

# %%
data['Fare_Range']=pd.qcut(data['Fare'],4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# /tmp/ipykernel_74/2701727214.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# <style type="text/css">
# #T_569c7_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_569c7_row1_col0 {
#   background-color: #b9dc66;
#   color: #000000;
# }
# #T_569c7_row2_col0 {
#   background-color: #54aa66;
#   color: #f1f1f1;
# }
# #T_569c7_row3_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_569c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_569c7_level0_col0" class="col_heading level0 col0" >Survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare_Range</th>
# ...

# %%
data['Fare_cat']=0
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)
# Out:
# /tmp/ipykernel_74/3254487197.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Sex'].replace(['male','female'],[0,1],inplace=True)
# /tmp/ipykernel_74/3254487197.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Sex'].replace(['male','female'],[0,1],inplace=True)
# ...

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
